# %% [markdown]
# ## Bus Analysis

# %%
import xml.etree.ElementTree as ET
import csv
import os
import datetime
import pandas as pd
import glob

# %%
def importJourneyDataToCSV(_fileAddress):
    print("File Address = " + _fileAddress)

    if "BusData_" not in _fileAddress:
        return -1

    tree = ET.parse(_fileAddress)
    root = tree.getroot()
    
    fileName = _fileAddress.split("/")[-1]

    if root.tag != "Siri":
        print("{0}is not a correct Data file".format(_fileAddress))
        return 0
    #root[0] is <Element 'ServiceDelivery' at 0x109773278>
    ServiceDelivery=root[0]
    if(ServiceDelivery.tag != "ServiceDelivery"):
        print("Var ServiceDelivery = " + ServiceDelivery.tag)

    #root[0][0] is <Element 'ResponseTimestamp' at 0x1097732c8>
    ResponseTimestamp = root[0][0]
    if(ResponseTimestamp.tag !="ResponseTimestamp"):
        print("Var ResponseTimestamp = " + ResponseTimestamp.tag)

    #root[0][1] is "<Element 'VehicleMonitoringDelivery' at 0x1097733b8>"
    VehicleMonitoringDelivery = root[0][1]
    if(VehicleMonitoringDelivery.tag != "VehicleMonitoringDelivery"):
        print("Var VehicleMonitoringDelivery = " + VehicleMonitoringDelivery.tag)

    #root[0][2] is "<Element 'SituationExchangeDelivery' at 0x10a835278>"
    SituationExchangeDelivery = root[0][2]
    if(SituationExchangeDelivery.tag != "SituationExchangeDelivery"):
        print("Var SituationExchangeDelivery = " + SituationExchangeDelivery.tag)
        
    df_ = pd.DataFrame( columns=['LineRef','DirectionRef', 'DatedVehicleJourneyRef', 'DataFrameRef', 'JourneyPatternRef', 
                            'OriginRef', 'DestinationRef', 'DestinationName', 'RecordedAtTime', 'Latitude', 'Longitude', 'Bearing', 'ProgressRate', 'progressStatus', 'fileName'] )
        
    #Read vehicles' position and time 
    for VehicleActivity in VehicleMonitoringDelivery.findall("VehicleActivity"):

        #Get Line Ref
        for MonitoredVehicleJourney in VehicleActivity.findall("MonitoredVehicleJourney"):

            # Line Name
            lineRef = MonitoredVehicleJourney.find("LineRef").text
            directionRef = MonitoredVehicleJourney.find("DirectionRef").text
            journeyRef = MonitoredVehicleJourney.find("FramedVehicleJourneyRef/DatedVehicleJourneyRef").text
            dateFrameRef = MonitoredVehicleJourney.find("FramedVehicleJourneyRef/DataFrameRef").text

        
            pattern = MonitoredVehicleJourney.find("JourneyPatternRef").text
            origin = MonitoredVehicleJourney.find("OriginRef").text
            destination = MonitoredVehicleJourney.find("DestinationRef").text
            destinationName = MonitoredVehicleJourney.find("DestinationName").text            
            
            
            timeText = VehicleActivity.find("RecordedAtTime").text
            lat = MonitoredVehicleJourney.find("VehicleLocation/Latitude").text
            lon = MonitoredVehicleJourney.find("VehicleLocation/Longitude").text
            bearing = MonitoredVehicleJourney.find("Bearing").text
            progressRate = MonitoredVehicleJourney.find("ProgressRate").text
            progressStatus = "None"
            if MonitoredVehicleJourney.find("ProgressStatus") is None:
                pass
            else:
                progressStatus = MonitoredVehicleJourney.find("ProgressStatus").text

            
            tmp_se = pd.Series( [lineRef, directionRef, journeyRef, dateFrameRef, pattern, origin, destination, destinationName, 
# 2   MTA NYCT_M55             1     MTA NYCT_MQ_A9-Weekday-SDon-048500_M55_4
# 3   MTA NYCT_M42             0    MTA NYCT_MQ_A9-Weekday-SDon-051400_M42_11
# 4  MTA NYCT_M79+             0   MTA NYCT_MQ_A9-Weekday-SDon-051900_SB79_11
#
#   DataFrameRef JourneyPatternRef   OriginRef DestinationRef  \
# 0   2019-02-12       MTA_M550034  MTA_803184     MTA_803081
# 1   2019-02-12     MTA_SBS860049  MTA_405003     MTA_803043
# 2   2019-02-12       MTA_M550035  MTA_803080     MTA_803185
# 3   2019-02-12       MTA_M420133  MTA_803055     MTA_903046
# 4   2019-02-12      MTA_SB790011  MTA_403522     MTA_401878
#
#                             DestinationName                 RecordedAtTime  \
# 0                                44 ST 6 AV  2019-02-12T08:45:33.000-05:00
# 1  SELECT BUS WESTSIDE WEST END AV CROSSTWN  2019-02-12T08:45:53.000-05:00
# 2                               SOUTH FERRY  2019-02-12T08:45:34.000-05:00
# 3                       UN - 1 AV CROSSTOWN  2019-02-12T08:45:28.000-05:00
# 4  SELECT BUS YRKVLLE EAST END AV CROSSTOWN  2019-02-12T08:45:49.000-05:00
#
#     Latitude  Longitude    Bearing    ProgressRate progressStatus  \
# 0  40.743435 -73.992396   52.73974  normalProgress           None
# 1  40.788189 -73.976238  157.56291  normalProgress           None
# 2  40.702345 -74.013804  327.09476  normalProgress           None
# 3  40.760944 -73.998622  336.37064  normalProgress           None
# 4  40.783061 -73.974065  336.02057  normalProgress           None
#
#                       fileName
# 0  BusData_20190212_084600.xml
# 1  BusData_20190212_084600.xml
# 2  BusData_20190212_084600.xml
# 3  BusData_20190212_084600.xml
# 4  BusData_20190212_084600.xml

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 309744 entries, 0 to 3076
# Data columns (total 15 columns):
# LineRef                   309744 non-null object
# DirectionRef              309744 non-null int64
# DatedVehicleJourneyRef    309744 non-null object
# DataFrameRef              309744 non-null object
# JourneyPatternRef         309744 non-null object
# OriginRef                 309744 non-null object
# DestinationRef            309744 non-null object
# DestinationName           309744 non-null object
# RecordedAtTime            309744 non-null object
# Latitude                  309744 non-null float64
# Longitude                 309744 non-null float64
# Bearing                   309744 non-null float64
# ProgressRate              309744 non-null object
# progressStatus            309744 non-null object
# fileName                  309744 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 37.8+ MB

# %%
df_all["time_dt"] = pd.to_datetime(df_all["RecordedAtTime"])

# %%
df_all.head()
# Out:
#          LineRef  DirectionRef                       DatedVehicleJourneyRef  \
# 0   MTA NYCT_M55             0     MTA NYCT_MQ_A9-Weekday-SDon-049500_M55_3
# 1  MTA NYCT_M86+             1  MTA NYCT_MQ_A9-Weekday-SDon-050200_SBS86_19
# 2   MTA NYCT_M55             1     MTA NYCT_MQ_A9-Weekday-SDon-048500_M55_4
# 3   MTA NYCT_M42             0    MTA NYCT_MQ_A9-Weekday-SDon-051400_M42_11
# 4  MTA NYCT_M79+             0   MTA NYCT_MQ_A9-Weekday-SDon-051900_SB79_11
#
#   DataFrameRef JourneyPatternRef   OriginRef DestinationRef  \
# 0   2019-02-12       MTA_M550034  MTA_803184     MTA_803081
# 1   2019-02-12     MTA_SBS860049  MTA_405003     MTA_803043
# 2   2019-02-12       MTA_M550035  MTA_803080     MTA_803185
# 3   2019-02-12       MTA_M420133  MTA_803055     MTA_903046
# 4   2019-02-12      MTA_SB790011  MTA_403522     MTA_401878
#
#                             DestinationName                 RecordedAtTime  \
# 0                                44 ST 6 AV  2019-02-12T08:45:33.000-05:00
# 1  SELECT BUS WESTSIDE WEST END AV CROSSTWN  2019-02-12T08:45:53.000-05:00
# 2                               SOUTH FERRY  2019-02-12T08:45:34.000-05:00
# 3                       UN - 1 AV CROSSTOWN  2019-02-12T08:45:28.000-05:00
# 4  SELECT BUS YRKVLLE EAST END AV CROSSTOWN  2019-02-12T08:45:49.000-05:00
#
#     Latitude  Longitude    Bearing    ProgressRate progressStatus  \
# 0  40.743435 -73.992396   52.73974  normalProgress           None
# 1  40.788189 -73.976238  157.56291  normalProgress           None
# 2  40.702345 -74.013804  327.09476  normalProgress           None
# 3  40.760944 -73.998622  336.37064  normalProgress           None
# 4  40.783061 -73.974065  336.02057  normalProgress           None
#
#                       fileName                   time_dt
# 0  BusData_20190212_084600.xml 2019-02-12 08:45:33-05:00
# 1  BusData_20190212_084600.xml 2019-02-12 08:45:53-05:00
# 2  BusData_20190212_084600.xml 2019-02-12 08:45:34-05:00
# 3  BusData_20190212_084600.xml 2019-02-12 08:45:28-05:00
# 4  BusData_20190212_084600.xml 2019-02-12 08:45:49-05:00

# %% [markdown]
# #### Get the data from 7:30 am to 9:30 am

# %%
df_selected  = df_all[(df_all['time_dt'] >= '2019-2-12 07:30:00') & (df_all['time_dt'] <= '2019-2-12 09:30:00')]

# %%
df_selected = df_selected.sort_values(by=['RecordedAtTime'])
df_selected = df_selected.reset_index().drop("index", axis = 1)

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208279 entries, 0 to 208278
# Data columns (total 16 columns):
# LineRef                   208279 non-null object
# DirectionRef              208279 non-null int64
# DatedVehicleJourneyRef    208279 non-null object
# DataFrameRef              208279 non-null object
# JourneyPatternRef         208279 non-null object
# OriginRef                 208279 non-null object
# DestinationRef            208279 non-null object
# DestinationName           208279 non-null object
# RecordedAtTime            208279 non-null object
# Latitude                  208279 non-null float64
# Longitude                 208279 non-null float64
# Bearing                   208279 non-null float64
# ProgressRate              208279 non-null object
# progressStatus            208279 non-null object
# fileName                  208279 non-null object
# time_dt                   208279 non-null datetime64[ns, pytz.FixedOffset(-300)]
# dtypes: datetime64[ns, pytz.FixedOffset(-300)](1), float64(3), int64(1), object(11)
# memory usage: 25.4+ MB

# %%
pd.concat([df_selected.head(), df_selected.tail()])
# Out:
#               LineRef  DirectionRef  \
# 0        MTA NYCT_Q16             1
# 1        MTA NYCT_M42             1
# 2          MTABC_QM34             1
# 3        MTA NYCT_Q43             1
# 4        MTA NYCT_Q31             1
# 208274      MTABC_Q64             1
# 208275   MTA NYCT_B38             1
# 208276  MTA NYCT_M101             1
# 208277   MTA NYCT_M57             1
# 208278     MTABC_Q111             1
#
#                              DatedVehicleJourneyRef DataFrameRef  \
# 0          MTA NYCT_CS_A9-Weekday-SDon-045000_Q16_5   2019-02-12
# 1          MTA NYCT_MQ_A9-Weekday-SDon-044900_M42_5   2019-02-12
# 2             MTABC_22501199-LGPA9-LG_A9-Weekday-10   2019-02-12
# 3          MTA NYCT_QV_A9-Weekday-SDon-042600_Q43_7   2019-02-12
# 4       MTA NYCT_CS_A9-Weekday-SDon-039500_MISC_740   2019-02-12
# 208274   MTABC_22560192-BPPA9-BP_A9-Weekday-10-SDon   2019-02-12
# 208275   MTA NYCT_GA_A9-Weekday-SDon-052400_B38_224   2019-02-12
# 208276   MTA NYCT_OH_A9-Weekday-SDon-044600_M101_23   2019-02-12
# 208277     MTA NYCT_MQ_A9-Weekday-SDon-054100_M57_7   2019-02-12
# 208278   MTABC_22561224-BPPA9-BP_A9-Weekday-10-SDon   2019-02-12
#
#        JourneyPatternRef   OriginRef DestinationRef  \
# 0            MTA_Q160039  MTA_504445     MTA_804050
# 1            MTA_M420134  MTA_403249     MTA_903082
# 2           MTA_QM340039  MTA_504366     MTA_405403
# 3            MTA_Q430188  MTA_502085     MTA_904095
# 4            MTA_Q310171  MTA_501249     MTA_904095
# 208274       MTA_Q640095  MTA_551840     MTA_982087
# 208275       MTA_B380161  MTA_503707     MTA_901070
# 208276      MTA_M1010381  MTA_400448     MTA_903148
# 208277       MTA_M570101  MTA_404938     MTA_400854
# 208278      MTA_Q1110273  MTA_552363     MTA_552285
#
#                                       DestinationName  \
# 0                 FLUSHING MAIN ST STATION via UTOPIA
# 1                                42 ST PIER CROSSTOWN
# 2                         EAST MIDTOWN 55 ST via 3 AV
# 3                   LTD JAMAICA LIRR STA via HILLSIDE
# 4                                        JAMAICA LIRR
# 208274  FOREST HILLS 71 AV STA via JEWEL AV via 69 RD
# 208275                         DNTWN BKLYN TILLARY ST
# 208276               LTD EAST VILLAGE 6 ST via LEX AV
# 208277                   WEST SIDE BWAY - 72 ST XTOWN
# 208278  ROSEDALE F. LEWIS BL via BREWER BL via 147 AV
#
#                        RecordedAtTime   Latitude  Longitude     Bearing  \
# 0       2019-02-12T07:30:00.000-05:00  40.790069 -73.781871  253.178590
# 1       2019-02-12T07:30:01.000-05:00  40.748384 -73.969951   53.841816
# 2       2019-02-12T07:30:01.000-05:00  40.701709 -73.894871  108.928600
# 3       2019-02-12T07:30:02.000-05:00  40.713097 -73.782032  196.189210
# 4       2019-02-12T07:30:02.000-05:00  40.700268 -73.808673  291.037500
# 208274  2019-02-12T09:29:59.000-05:00  40.731787 -73.805534  177.108730
# 208275  2019-02-12T09:29:59.000-05:00  40.689975 -73.981907  181.169140
# 208276  2019-02-12T09:29:59.000-05:00  40.737226 -73.984309  233.914930
# 208277  2019-02-12T09:29:59.000-05:00  40.766664 -73.982730  156.614780
# 208278  2019-02-12T09:29:59.000-05:00  40.668405 -73.771856  310.055940
#
#           ProgressRate progressStatus                     fileName  \
# 0       normalProgress           None  BusData_20190212_073000.xml
# 1       normalProgress           None  BusData_20190212_073000.xml
# 2       normalProgress           None  BusData_20190212_073200.xml
# 3       normalProgress           None  BusData_20190212_073200.xml
# 4       normalProgress           None  BusData_20190212_073000.xml
# 208274      noProgress        layover  BusData_20190212_093000.xml
# 208275  normalProgress           None  BusData_20190212_093000.xml
# 208276  normalProgress           None  BusData_20190212_093000.xml
# 208277  normalProgress           None  BusData_20190212_093000.xml
# 208278  normalProgress           None  BusData_20190212_093000.xml
#
#                          time_dt
# 0      2019-02-12 07:30:00-05:00
# 1      2019-02-12 07:30:01-05:00
# 2      2019-02-12 07:30:01-05:00
# 3      2019-02-12 07:30:02-05:00
# 4      2019-02-12 07:30:02-05:00
# 208274 2019-02-12 09:29:59-05:00
# 208275 2019-02-12 09:29:59-05:00
# 208276 2019-02-12 09:29:59-05:00
# 208277 2019-02-12 09:29:59-05:00
# 208278 2019-02-12 09:29:59-05:00

# %%
columnsLists= list(df_selected.columns)
columnsLists.pop(-2)
columnsLists
# Out:
# ['LineRef',
#  'DirectionRef',
#  'DatedVehicleJourneyRef',
#  'DataFrameRef',
#  'JourneyPatternRef',
#  'OriginRef',
#  'DestinationRef',
#  'DestinationName',
#  'RecordedAtTime',
#  'Latitude',
#  'Longitude',
#  'Bearing',
#  'ProgressRate',
#  'progressStatus',
#  'time_dt']

# %%
# The duplicated records
df_selected[df_selected.duplicated(keep = False)].sort_values(by=['DatedVehicleJourneyRef', 'RecordedAtTime'])
# Out:
# Empty DataFrame
# Columns: [LineRef, DirectionRef, DatedVehicleJourneyRef, DataFrameRef, JourneyPatternRef, OriginRef, DestinationRef, DestinationName, RecordedAtTime, Latitude, Longitude, Bearing, ProgressRate, progressStatus, fileName, time_dt]
# Index: []

# %%
# The records which have the same data in the "DatedVehicleJourneyRef" and "RecordedAtTime" columns
df_selected[df_selected.duplicated(subset = ['DatedVehicleJourneyRef', 'RecordedAtTime'], keep = False)].sort_values(by=['DatedVehicleJourneyRef', 'RecordedAtTime'])
# Out:
#                LineRef  DirectionRef  \
# 23857   MTA NYCT_SIM22             0
# 23909   MTA NYCT_SIM22             0
# 4857      MTA NYCT_S53             0
# 4878      MTA NYCT_S53             0
# 100313   MTA NYCT_SIM3             0
# 100315   MTA NYCT_SIM3             0
# 143641   MTA NYCT_SIM3             0
# 143676   MTA NYCT_SIM3             0
# 98798     MTA NYCT_S76             0
# 98810     MTA NYCT_S76             0
# 103385   MTA NYCT_SIM3             0
# 103390   MTA NYCT_SIM3             0
# 15        MTA NYCT_S98             0
# 16        MTA NYCT_S98             0
# 88284     MTA NYCT_S53             0
# 88361     MTA NYCT_S53             0
# 108572  MTA NYCT_SIM34             0
# 108588  MTA NYCT_SIM34             0
# 92958     MTA NYCT_S53             0
# 92960     MTA NYCT_S53             0
# 79239     MTA NYCT_S53             1
# 79246     MTA NYCT_S53             1
# 81274    MTA NYCT_SIM3             0
# 81312    MTA NYCT_SIM3             0
# 127236  MTA NYCT_SIM34             0
# 127239  MTA NYCT_SIM34             0
# 147952    MTA NYCT_S53             0
# 147981    MTA NYCT_S53             0
# 111461    MTA NYCT_S93             0
# 111488    MTA NYCT_S93             0
# ...                ...           ...
# 89102        MTABC_Q07             0
# 89141        MTABC_Q07             0
# 6851         MTABC_Q07             1
# 6868         MTABC_Q07             1
# 24938        MTABC_Q40             0
# 25020        MTABC_Q40             0
# 121337       MTABC_Q40             0
# 121348       MTABC_Q40             0
# 78250        MTABC_Q09             0
# 78268        MTABC_Q09             0
# 166405       MTABC_Q06             0
# 166406       MTABC_Q06             0
# 167270      MTABC_QM18             1
# 167284      MTABC_QM18             1
# 159889      MTABC_QM16             1
# 159892      MTABC_QM16             1
# 34676       MTABC_QM15             1
# 34697       MTABC_QM15             1
# 75044       MTABC_QM15             1
# 75046       MTABC_QM15             1
# 18527       MTABC_QM15             1
# 18545       MTABC_QM15             1
# 102998      MTABC_QM15             1
# 103071      MTABC_QM15             1
# 51768        MTABC_Q11             1
# 51781        MTABC_Q11             1
# 14137        MTABC_Q22             1
# 14186        MTABC_Q22             1
# 199638       MTABC_Q41             1
# 199685       MTABC_Q41             1
#
#                              DatedVehicleJourneyRef DataFrameRef  \
# 23857   MTA NYCT_CA_E9-Weekday-SDon-039000_MISC_452   2019-02-12
# 23909   MTA NYCT_CA_E9-Weekday-SDon-039000_MISC_452   2019-02-12
# 4857    MTA NYCT_CA_E9-Weekday-SDon-041000_MISC_495   2019-02-12
# 4878    MTA NYCT_CA_E9-Weekday-SDon-041000_MISC_495   2019-02-12
# 100313  MTA NYCT_CA_E9-Weekday-SDon-041000_SIM3_308   2019-02-12
# 100315  MTA NYCT_CA_E9-Weekday-SDon-041000_SIM3_308   2019-02-12
# 143641  MTA NYCT_CA_E9-Weekday-SDon-041000_SIM3_308   2019-02-12
# 143676  MTA NYCT_CA_E9-Weekday-SDon-041000_SIM3_308   2019-02-12
# 98798   MTA NYCT_CA_E9-Weekday-SDon-041100_MISC_424   2019-02-12
# 98810   MTA NYCT_CA_E9-Weekday-SDon-041100_MISC_424   2019-02-12
# 103385  MTA NYCT_CA_E9-Weekday-SDon-042000_SIM3_309   2019-02-12
# 103390  MTA NYCT_CA_E9-Weekday-SDon-042000_SIM3_309   2019-02-12
# 15      MTA NYCT_CA_E9-Weekday-SDon-044800_MISC_455   2019-02-12
# 16      MTA NYCT_CA_E9-Weekday-SDon-044800_MISC_455   2019-02-12
# 88284   MTA NYCT_CA_E9-Weekday-SDon-045000_MISC_438   2019-02-12
# 88361   MTA NYCT_CA_E9-Weekday-SDon-045000_MISC_438   2019-02-12
# 108572  MTA NYCT_CA_E9-Weekday-SDon-045000_MISC_513   2019-02-12
# 108588  MTA NYCT_CA_E9-Weekday-SDon-045000_MISC_513   2019-02-12
# 92958   MTA NYCT_CA_E9-Weekday-SDon-045700_MISC_440   2019-02-12
# 92960   MTA NYCT_CA_E9-Weekday-SDon-045700_MISC_440   2019-02-12
# 79239   MTA NYCT_CA_E9-Weekday-SDon-045800_MISC_477   2019-02-12
# 79246   MTA NYCT_CA_E9-Weekday-SDon-045800_MISC_477   2019-02-12
# 81274   MTA NYCT_CA_E9-Weekday-SDon-046000_SIM3_301   2019-02-12
# 81312   MTA NYCT_CA_E9-Weekday-SDon-046000_SIM3_301   2019-02-12
# 127236  MTA NYCT_CA_E9-Weekday-SDon-048000_MISC_435   2019-02-12
# 127239  MTA NYCT_CA_E9-Weekday-SDon-048000_MISC_435   2019-02-12
# 147952   MTA NYCT_CA_E9-Weekday-SDon-048000_S53_304   2019-02-12
# 147981   MTA NYCT_CA_E9-Weekday-SDon-048000_S53_304   2019-02-12
# 111461  MTA NYCT_CA_E9-Weekday-SDon-048500_MISC_469   2019-02-12
# 111488  MTA NYCT_CA_E9-Weekday-SDon-048500_MISC_469   2019-02-12
# ...                                             ...          ...
# 89102    MTABC_22617722-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 89141    MTABC_22617722-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 6851     MTABC_22617871-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 6868     MTABC_22617871-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 24938    MTABC_22617905-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 25020    MTABC_22617905-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 121337   MTABC_22617914-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 121348   MTABC_22617914-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 78250    MTABC_22618095-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 78268    MTABC_22618095-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 166405   MTABC_22618359-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 166406   MTABC_22618359-JKPA9-JK_A9-Weekday-10-SDon   2019-02-12
# 167270   MTABC_22631156-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 167284   MTABC_22631156-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 159889   MTABC_22631193-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 159892   MTABC_22631193-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 34676    MTABC_22631211-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 34697    MTABC_22631211-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 75044    MTABC_22631214-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 75046    MTABC_22631214-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 18527    MTABC_22631240-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 18545    MTABC_22631240-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 102998   MTABC_22631245-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 103071   MTABC_22631245-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 51768    MTABC_22631339-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 51781    MTABC_22631339-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 14137    MTABC_22631702-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 14186    MTABC_22631702-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 199638   MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 199685   MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
#
#        JourneyPatternRef   OriginRef DestinationRef  \
# 23857      MTA_SIM220039  MTA_200994     MTA_402214
# 23909      MTA_SIM220039  MTA_200994     MTA_402214
# 4857         MTA_S530127  MTA_202740     MTA_801069
# 4878         MTA_S530127  MTA_202740     MTA_801069
# 100313      MTA_SIM30106  MTA_905019     MTA_903036
# 100315      MTA_SIM30106  MTA_905019     MTA_903036
# 143641      MTA_SIM30106  MTA_905019     MTA_903036
# 143676      MTA_SIM30106  MTA_905019     MTA_903036
# 98798        MTA_S760080  MTA_203896     MTA_805015
# 98810        MTA_S760080  MTA_203896     MTA_805015
# 103385      MTA_SIM30106  MTA_905019     MTA_903036
# 103390      MTA_SIM30106  MTA_905019     MTA_903036
# 15           MTA_S980046  MTA_203420     MTA_805017
# 16           MTA_S980046  MTA_203420     MTA_805017
# 88284        MTA_S530127  MTA_202740     MTA_801069
# 88361        MTA_S530127  MTA_202740     MTA_801069
# 108572     MTA_SIM340058  MTA_202823     MTA_400919
# 108588     MTA_SIM340058  MTA_202823     MTA_400919
# 92958        MTA_S530127  MTA_202740     MTA_801069
# 92960        MTA_S530127  MTA_202740     MTA_801069
# 79239        MTA_S530128  MTA_905059     MTA_905105
# 79246        MTA_S530128  MTA_905059     MTA_905105
# 81274       MTA_SIM30106  MTA_905019     MTA_903036
# 81312       MTA_SIM30106  MTA_905019     MTA_903036
# 127236     MTA_SIM340058  MTA_202823     MTA_400919
# 127239     MTA_SIM340058  MTA_202823     MTA_400919
# 147952       MTA_S530127  MTA_202740     MTA_801069
# 147981       MTA_S530127  MTA_202740     MTA_801069
# 111461       MTA_S930093  MTA_805166     MTA_905142
# 111488       MTA_S930093  MTA_805166     MTA_905142
# ...                  ...         ...            ...
# 89102        MTA_Q070231  MTA_350000     MTA_982156
# 89141        MTA_Q070231  MTA_350000     MTA_982156
# 6851         MTA_Q070204  MTA_550114     MTA_550138
# 6868         MTA_Q070204  MTA_550114     MTA_550138
# 24938        MTA_Q400137  MTA_553246     MTA_551473
# 25020        MTA_Q400137  MTA_553246     MTA_551473
# 121337       MTA_Q400137  MTA_553246     MTA_551473
# 121348       MTA_Q400137  MTA_553246     MTA_551473
# 78250        MTA_Q090118  MTA_550220     MTA_982152
# 78268        MTA_Q090118  MTA_550220     MTA_982152
# 166405       MTA_Q060269  MTA_550001     MTA_982152
# 166406       MTA_Q060269  MTA_550001     MTA_982152
# 167270      MTA_QM180067  MTA_550293     MTA_450030
# 167284      MTA_QM180067  MTA_550293     MTA_450030
# 159889      MTA_QM160089  MTA_553113     MTA_450030
# 159892      MTA_QM160089  MTA_553113     MTA_450030
# 34676       MTA_QM150121  MTA_550499     MTA_450030
# 34697       MTA_QM150121  MTA_550499     MTA_450030
# 75044       MTA_QM150121  MTA_550499     MTA_450030
# 75046       MTA_QM150121  MTA_550499     MTA_450030
# 18527       MTA_QM150121  MTA_550499     MTA_450030
# 18545       MTA_QM150121  MTA_550499     MTA_450030
# 102998      MTA_QM150122  MTA_553137     MTA_450030
# 103071      MTA_QM150122  MTA_553137     MTA_450030
# 51768        MTA_Q110386  MTA_552993     MTA_550500
# 51781        MTA_Q110386  MTA_552993     MTA_550500
# 14137        MTA_Q220630  MTA_550825     MTA_982151
# 14186        MTA_Q220630  MTA_550825     MTA_982151
# 199638       MTA_Q410266  MTA_551528     MTA_551482
# 199685       MTA_Q410266  MTA_551528     MTA_551482
#
#                                           DestinationName  \
# 23857                    MIDTOWN via 42 ST via MADISON AV
# 23909                    MIDTOWN via 42 ST via MADISON AV
# 4857                                  BAY RIDGE 86 ST STA
# 4878                                  BAY RIDGE 86 ST STA
# 100313                         MIDTOWN via 23 ST via 6 AV
# 100315                         MIDTOWN via 23 ST via 6 AV
# 143641                         MIDTOWN via 23 ST via 6 AV
# 143676                         MIDTOWN via 23 ST via 6 AV
# 98798                                     ST GEORGE FERRY
# 98810                                     ST GEORGE FERRY
# 103385                         MIDTOWN via 23 ST via 6 AV
# 103390                         MIDTOWN via 23 ST via 6 AV
# 15                               LTD ST GEORGE via FOREST
# 16                               LTD ST GEORGE via FOREST
# 88284                                          VICTORY BL
# 88361                                          VICTORY BL
# 108572                      SOHO HOUSTON ST via CHURCH ST
# 108588                      SOHO HOUSTON ST via CHURCH ST
# 92958                                 BAY RIDGE 86 ST STA
# 92960                                 BAY RIDGE 86 ST STA
# 79239                                         PT RICHMOND
# 79246                                         PT RICHMOND
# 81274                          MIDTOWN via 23 ST via 6 AV
# 81312                          MIDTOWN via 23 ST via 6 AV
# 127236                      SOHO HOUSTON ST via CHURCH ST
# 127239                      SOHO HOUSTON ST via CHURCH ST
# 147952                                BAY RIDGE 86 ST STA
# 147981                                BAY RIDGE 86 ST STA
# 111461                 LTD BAY RIDGE 86 ST STA via VICTRY
# 111488                 LTD BAY RIDGE 86 ST STA via VICTRY
# ...                                                   ...
# 89102             JFK AIRPORT S. CARGO RD via ROCKAWAY BL
# 89141             JFK AIRPORT S. CARGO RD via ROCKAWAY BL
# 6851                         CROSS BAY BL via ROCKAWAY BL
# 6868                         CROSS BAY BL via ROCKAWAY BL
# 24938                  JAMAICA HILLSIDE AV via SUTPHIN BL
# 25020                  JAMAICA HILLSIDE AV via SUTPHIN BL
# 121337                 JAMAICA HILLSIDE AV via SUTPHIN BL
# 121348                 JAMAICA HILLSIDE AV via SUTPHIN BL
# 78250                                 JAMAICA 165 ST TERM
# 78268                                 JAMAICA 165 ST TERM
# 166405   LIMITED JAMAICA 165 ST TERMINAL via SUTPHIN BLVD
# 166406   LIMITED JAMAICA 165 ST TERMINAL via SUTPHIN BLVD
# 167270                             MIDTOWN 57 ST via 6 AV
# 167284                             MIDTOWN 57 ST via 6 AV
# 159889                             MIDTOWN 57 ST via 6 AV
# 159892                             MIDTOWN 57 ST via 6 AV
# 34676                              MIDTOWN 57 ST via 6 AV
# 34697                              MIDTOWN 57 ST via 6 AV
# 75044                              MIDTOWN 57 ST via 6 AV
# 75046                              MIDTOWN 57 ST via 6 AV
# 18527                              MIDTOWN 57 ST via 6 AV
# 18545                              MIDTOWN 57 ST via 6 AV
# 102998                             MIDTOWN 57 ST via 6 AV
# 103071                             MIDTOWN 57 ST via 6 AV
# 51768                          PITKIN AV via WOODHAVEN BL
# 51781                          PITKIN AV via WOODHAVEN BL
# 14137   ROXBURY B. 169 ST via BCH CHANNEL DR via ROCKW...
# 14186   ROXBURY B. 169 ST via BCH CHANNEL DR via ROCKW...
# 199638                                HOWARD BEACH 164 AV
# 199685                                HOWARD BEACH 164 AV
#
#                        RecordedAtTime   Latitude  Longitude     Bearing  \
# 23857   2019-02-12T07:43:46.000-05:00  40.756219 -73.976775   53.396748
# 23909   2019-02-12T07:43:46.000-05:00  40.756219 -73.976775   53.396748
# 4857    2019-02-12T07:33:39.000-05:00  40.601650 -74.062705  352.874970
# 4878    2019-02-12T07:33:39.000-05:00  40.601650 -74.062705  352.874970
# 100313  2019-02-12T08:25:26.000-05:00  40.765835 -73.976589  156.349900
# 100315  2019-02-12T08:25:26.000-05:00  40.765835 -73.976589  156.349900
# 143641  2019-02-12T08:49:33.000-05:00  40.765949 -73.976849  156.349900
# 143676  2019-02-12T08:49:33.000-05:00  40.765949 -73.976849  156.349900
# 98798   2019-02-12T08:23:47.000-05:00  40.643585 -74.073001  199.003080
# 98810   2019-02-12T08:23:47.000-05:00  40.643585 -74.073001  199.003080
# 103385  2019-02-12T08:25:55.000-05:00  40.760871 -73.979684   53.806793
# 75046   2019-02-12T08:11:34.000-05:00  40.664370 -73.849839  117.904686
# 18527   2019-02-12T07:41:31.000-05:00  40.745861 -73.976966  227.320890
# 18545   2019-02-12T07:41:31.000-05:00  40.745861 -73.976966  227.320890
# 102998  2019-02-12T08:25:52.000-05:00  40.746632 -73.980191  156.970500
# 103071  2019-02-12T08:25:52.000-05:00  40.746632 -73.980191  156.970500
# 51768   2019-02-12T07:59:29.000-05:00  40.718625 -73.864037  314.473000
# 51781   2019-02-12T07:59:29.000-05:00  40.718625 -73.864037  314.473000
# 14137   2019-02-12T07:37:57.000-05:00  40.588090 -73.806575  185.656780
# 14186   2019-02-12T07:37:57.000-05:00  40.588090 -73.806575  185.656780
# 199638  2019-02-12T09:23:58.000-05:00  40.659343 -73.840032  284.250580
# 199685  2019-02-12T09:23:58.000-05:00  40.659343 -73.840032  284.250580
#
#           ProgressRate progressStatus                     fileName  \
# 23857   normalProgress           None  BusData_20190212_074400.xml
# 23909   normalProgress           None  BusData_20190212_074600.xml
# 4857    normalProgress           None  BusData_20190212_073600.xml
# 4878    normalProgress           None  BusData_20190212_073400.xml
# 100313      noProgress        layover  BusData_20190212_082800.xml
# 100315      noProgress        layover  BusData_20190212_082600.xml
# 143641      noProgress        layover  BusData_20190212_085200.xml
# 143676      noProgress        layover  BusData_20190212_085000.xml
# 98798       noProgress        layover  BusData_20190212_082400.xml
# 98810       noProgress        layover  BusData_20190212_082600.xml
# 103385  normalProgress           None  BusData_20190212_082800.xml
# 103390  normalProgress           None  BusData_20190212_082600.xml
# 15      normalProgress           None  BusData_20190212_073200.xml
# 16      normalProgress           None  BusData_20190212_073000.xml
# 88284   normalProgress           None  BusData_20190212_081800.xml
# 88361   normalProgress           None  BusData_20190212_082000.xml
# 108572  normalProgress           None  BusData_20190212_083000.xml
# 108588  normalProgress           None  BusData_20190212_083200.xml
# 92958   normalProgress           None  BusData_20190212_082200.xml
# 92960   normalProgress           None  BusData_20190212_082400.xml
# 79239   normalProgress           None  BusData_20190212_081600.xml
# 79246   normalProgress           None  BusData_20190212_081400.xml
# 81274   normalProgress           None  BusData_20190212_081400.xml
# 81312   normalProgress           None  BusData_20190212_081600.xml
# 127236  normalProgress           None  BusData_20190212_084000.xml
# 127239  normalProgress           None  BusData_20190212_084200.xml
# 147952  normalProgress           None  BusData_20190212_085200.xml
# 147981  normalProgress           None  BusData_20190212_085400.xml
# 111461  normalProgress           None  BusData_20190212_083200.xml
# 111488  normalProgress           None  BusData_20190212_083400.xml
# ...                ...            ...                          ...
# 89102   normalProgress           None  BusData_20190212_082000.xml
# 89141   normalProgress           None  BusData_20190212_081800.xml
# 6851    normalProgress           None  BusData_20190212_073400.xml
# 6868    normalProgress           None  BusData_20190212_073600.xml
# 24938   normalProgress           None  BusData_20190212_074400.xml
# 25020   normalProgress           None  BusData_20190212_074400.xml
# 121337  normalProgress           None  BusData_20190212_083600.xml
# 121348  normalProgress           None  BusData_20190212_083600.xml
# 78250   normalProgress           None  BusData_20190212_081400.xml
# 167284 2019-02-12 09:03:36-05:00
# 159889 2019-02-12 08:59:24-05:00
# 159892 2019-02-12 08:59:24-05:00
# 34676  2019-02-12 07:49:42-05:00
# 34697  2019-02-12 07:49:42-05:00
# 75044  2019-02-12 08:11:34-05:00
# 75046  2019-02-12 08:11:34-05:00
# 18527  2019-02-12 07:41:31-05:00
# 18545  2019-02-12 07:41:31-05:00
# 102998 2019-02-12 08:25:52-05:00
# 103071 2019-02-12 08:25:52-05:00
# 51768  2019-02-12 07:59:29-05:00
# 51781  2019-02-12 07:59:29-05:00
# 14137  2019-02-12 07:37:57-05:00
# 14186  2019-02-12 07:37:57-05:00
# 199638 2019-02-12 09:23:58-05:00
# 199685 2019-02-12 09:23:58-05:00
#
# [1312 rows x 16 columns]

# %%
# The records which have the same data in the "DatedVehicleJourneyRef" and "filename" columns
df_selected[df_selected.duplicated(subset = ['DatedVehicleJourneyRef', 'fileName'], keep = False)].sort_values(by=['DatedVehicleJourneyRef', 'RecordedAtTime'])
# Out:
#               LineRef  DirectionRef  \
# 9604     MTA NYCT_S54             0
# 10698    MTA NYCT_S54             0
# 131      MTA NYCT_S66             1
# 3430     MTA NYCT_S66             1
# 18072    MTA NYCT_S53             1
# 18086    MTA NYCT_S53             1
# 18576    MTA NYCT_S53             1
# 19867    MTA NYCT_S53             1
# 23220    MTA NYCT_S53             1
# 24957    MTA NYCT_S53             1
# 16203   MTA NYCT_SIM3             0
# 18091   MTA NYCT_SIM3             0
# 20087   MTA NYCT_SIM3             0
# 20609   MTA NYCT_SIM3             0
# 13019    MTA NYCT_S51             1
# 13616    MTA NYCT_S51             1
# 28852    MTA NYCT_S52             0
# 29186    MTA NYCT_S52             0
# 71342    MTA NYCT_S54             1
# 72016    MTA NYCT_S54             1
# 72965    MTA NYCT_S46             0
# 74204    MTA NYCT_S46             0
# 94371    MTA NYCT_S98             0
# 96043    MTA NYCT_S98             0
# 114614   MTA NYCT_S98             0
# 114827   MTA NYCT_S98             0
# 143712   MTA NYCT_S53             1
# 144596   MTA NYCT_S53             1
# 65539    MTA NYCT_S46             1
# 66673    MTA NYCT_S46             1
# ...               ...           ...
# 69532       MTABC_Q41             1
# 72946       MTABC_Q41             1
# 74124       MTABC_Q41             1
# 74952       MTABC_Q41             1
# 77643       MTABC_Q41             1
# 78578       MTABC_Q41             1
# 79258       MTABC_Q41             1
# 79389       MTABC_Q41             1
# 83291       MTABC_Q41             1
# 85452       MTABC_Q41             1
# 85878       MTABC_Q41             1
# 88008       MTABC_Q41             1
# 112810      MTABC_Q41             1
# 114626      MTABC_Q41             1
# 119751      MTABC_Q41             1
# 120747      MTABC_Q41             1
# 124134      MTABC_Q41             1
# 125136      MTABC_Q41             1
# 125878      MTABC_Q41             1
# 128527      MTABC_Q41             1
# 129322      MTABC_Q41             1
# 130184      MTABC_Q41             1
# 133580      MTABC_Q41             1
# 134301      MTABC_Q41             1
# 155078      MTABC_Q41             1
# 155373      MTABC_Q41             1
# 159017      MTABC_Q41             1
# 159421      MTABC_Q41             1
# 160164      MTABC_Q41             1
# 162777      MTABC_Q41             1
#
#                               DatedVehicleJourneyRef DataFrameRef  \
# 9604      MTA NYCT_CA_E9-Weekday-SDon-040500_S54_303   2019-02-12
# 10698     MTA NYCT_CA_E9-Weekday-SDon-040500_S54_303   2019-02-12
# 131      MTA NYCT_CA_E9-Weekday-SDon-042000_MISC_459   2019-02-12
# 3430     MTA NYCT_CA_E9-Weekday-SDon-042000_MISC_459   2019-02-12
# 18072     MTA NYCT_CA_E9-Weekday-SDon-043000_S53_305   2019-02-12
# 18086     MTA NYCT_CA_E9-Weekday-SDon-043000_S53_305   2019-02-12
# 18576     MTA NYCT_CA_E9-Weekday-SDon-043000_S53_305   2019-02-12
# 19867     MTA NYCT_CA_E9-Weekday-SDon-043000_S53_305   2019-02-12
# 23220     MTA NYCT_CA_E9-Weekday-SDon-043000_S53_305   2019-02-12
# 24957     MTA NYCT_CA_E9-Weekday-SDon-043000_S53_305   2019-02-12
# 16203    MTA NYCT_CA_E9-Weekday-SDon-044500_MISC_514   2019-02-12
# 18091    MTA NYCT_CA_E9-Weekday-SDon-044500_MISC_514   2019-02-12
# 20087    MTA NYCT_CA_E9-Weekday-SDon-044500_MISC_514   2019-02-12
# 20609    MTA NYCT_CA_E9-Weekday-SDon-044500_MISC_514   2019-02-12
# 13019   MTA NYCT_CA_E9-Weekday-SDon-045000_S4898_304   2019-02-12
# 13616   MTA NYCT_CA_E9-Weekday-SDon-045000_S4898_304   2019-02-12
# 28852    MTA NYCT_CA_E9-Weekday-SDon-045500_MISC_425   2019-02-12
# 29186    MTA NYCT_CA_E9-Weekday-SDon-045500_MISC_425   2019-02-12
# 71342     MTA NYCT_CA_E9-Weekday-SDon-046200_S54_304   2019-02-12
# 72016     MTA NYCT_CA_E9-Weekday-SDon-046200_S54_304   2019-02-12
# 72965   MTA NYCT_CA_E9-Weekday-SDon-047300_S4696_306   2019-02-12
# 74204   MTA NYCT_CA_E9-Weekday-SDon-047300_S4696_306   2019-02-12
# 94371   MTA NYCT_CA_E9-Weekday-SDon-047800_S4898_301   2019-02-12
# 96043   MTA NYCT_CA_E9-Weekday-SDon-047800_S4898_301   2019-02-12
# 114614  MTA NYCT_CA_E9-Weekday-SDon-047800_S4898_301   2019-02-12
# 114827  MTA NYCT_CA_E9-Weekday-SDon-047800_S4898_301   2019-02-12
# 143712   MTA NYCT_CA_E9-Weekday-SDon-048200_MISC_493   2019-02-12
# 144596   MTA NYCT_CA_E9-Weekday-SDon-048200_MISC_493   2019-02-12
# 65539    MTA NYCT_CA_E9-Weekday-SDon-048500_MISC_420   2019-02-12
# 66673    MTA NYCT_CA_E9-Weekday-SDon-048500_MISC_420   2019-02-12
# ...                                              ...          ...
# 69532     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 72946     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 74124     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 74952     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 77643     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 78578     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 79258     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 79389     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 83291     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 85452     MTABC_22632026-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 85878     MTABC_22632027-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 88008     MTABC_22632027-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 112810    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 114626    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 119751    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 120747    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 124134    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 125136    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 125878    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 128527    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 129322    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 130184    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 133580    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
# 134301    MTABC_22632029-FRPA9-FR_A9-Weekday-10-SDon   2019-02-12
#
# 13019   40.630857 -74.076565  252.561400  normalProgress           None
# 13616   40.597711 -74.062840  306.430850  normalProgress           None
# 28852   40.588179 -74.068750   44.664940  normalProgress           None
# 29186   40.592700 -74.071814  199.983110  normalProgress           None
# 71342   40.592817 -74.131677   11.560131  normalProgress           None
# 72016   40.598168 -74.125736  173.097060  normalProgress           None
# 72965   40.636033 -74.134930  359.262330  normalProgress           None
# 74204   40.633869 -74.125726    4.049582  normalProgress           None
# 94371   40.627062 -74.125356    7.574680  normalProgress           None
# 96043   40.631491 -74.094693  349.327120  normalProgress           None
# 114614  40.630479 -74.089318  352.164500  normalProgress           None
# 114827  40.640463 -74.171287   92.227050  normalProgress           None
# 143712  40.638433 -74.133022   52.539444  normalProgress           None
# 144596  40.639994 -74.131836   53.455030  normalProgress           None
# 65539   40.641822 -74.075528  228.012790  normalProgress           None
# 66673   40.643309 -74.073805  198.995350  normalProgress           None
# ...           ...        ...         ...             ...            ...
# 69532   40.706889 -73.795182  302.511900      noProgress        layover
# 72946   40.706889 -73.795182  302.511900      noProgress        layover
# 74124   40.706889 -73.795182  302.511900      noProgress        layover
# 74952   40.706889 -73.795182  302.511900      noProgress        layover
# 77643   40.706889 -73.795182  302.511900      noProgress        layover
# 78578   40.706889 -73.795182  302.511900      noProgress        layover
# 79258   40.706889 -73.795182  302.511900  normalProgress           None
# 79389   40.706889 -73.795182  302.511900      noProgress        layover
# 83291   40.706889 -73.795182  302.511900  normalProgress           None
# 85452   40.706889 -73.795182  302.511900      noProgress        layover
# 85878   40.706889 -73.795182  302.511900      noProgress        layover
# 88008   40.706889 -73.795182  302.511900      noProgress        layover
# 112810  40.706745 -73.794577  304.098400  normalProgress           None
# 114626  40.706889 -73.795182  302.511900      noProgress        layover
# 119751  40.706889 -73.795182  302.511900      noProgress        layover
# 120747  40.706889 -73.795182  302.511900  normalProgress           None
# 124134  40.706889 -73.795182  302.511900      noProgress        layover
# 125136  40.706889 -73.795182  302.511900      noProgress        layover
# 125878  40.706889 -73.795182  302.511900      noProgress        layover
# 128527  40.706889 -73.795182  302.511900      noProgress        layover
# 129322  40.706889 -73.795182  302.511900      noProgress        layover
# 130184  40.706889 -73.795182  302.511900      noProgress        layover
# 133580  40.705895 -73.793994  306.052430  normalProgress           None
# 134301  40.706889 -73.795182  302.511900      noProgress        layover
# 155078  40.686046 -73.816562  296.755830  normalProgress           None
# 155373  40.697549 -73.811748  196.984240  normalProgress           None
# 159017  40.682912 -73.819979  196.337070  normalProgress           None
# 159421  40.696003 -73.820688  185.029070  normalProgress           None
# 160164  40.692073 -73.819243  295.654050  normalProgress           None
# 162777  40.681659 -73.824395  195.389050  normalProgress           None
#
#                            fileName                   time_dt
# 9604    BusData_20190212_073600.xml 2019-02-12 07:35:49-05:00
# 10698   BusData_20190212_073600.xml 2019-02-12 07:35:58-05:00
# 131     BusData_20190212_073200.xml 2019-02-12 07:31:28-05:00
# 3430    BusData_20190212_073200.xml 2019-02-12 07:31:58-05:00
# 124134  BusData_20190212_083800.xml 2019-02-12 08:37:47-05:00
# 125136  BusData_20190212_083800.xml 2019-02-12 08:37:55-05:00
# 125878  BusData_20190212_084000.xml 2019-02-12 08:39:30-05:00
# 128527  BusData_20190212_084000.xml 2019-02-12 08:39:54-05:00
# 129322  BusData_20190212_084200.xml 2019-02-12 08:41:29-05:00
# 130184  BusData_20190212_084200.xml 2019-02-12 08:41:37-05:00
# 133580  BusData_20190212_084400.xml 2019-02-12 08:43:36-05:00
# 134301  BusData_20190212_084400.xml 2019-02-12 08:43:43-05:00
# 155078  BusData_20190212_085600.xml 2019-02-12 08:55:45-05:00
# 155373  BusData_20190212_085600.xml 2019-02-12 08:55:48-05:00
# 159017  BusData_20190212_085800.xml 2019-02-12 08:57:51-05:00
# 159421  BusData_20190212_085800.xml 2019-02-12 08:57:55-05:00
# 160164  BusData_20190212_090000.xml 2019-02-12 08:59:31-05:00
# 162777  BusData_20190212_090000.xml 2019-02-12 08:59:56-05:00
#
# [6794 rows x 16 columns]

# %% [markdown]
# #### Cleaning
# - Remove the "noProgress" data
# - Delete one of the two records which have the same data except for filename columns.
# - If there are two different records of the same time, delete both of them.
# - If there are two records in a file for the same "DatedVehicleJourneyRef", keep them. If there are any problems, try to solve them in the visualization process (openFrameworks)

# %%
df_selected = df_selected.query("ProgressRate == 'normalProgress'")

# %%
df_selected = df_selected.drop_duplicates(subset=columnsLists)

# %%
# The records which have the same data in the "DatedVehicleJourneyRef" and "RecordedAtTime" columns
df_selected[df_selected.duplicated(subset = ['DatedVehicleJourneyRef', 'RecordedAtTime'], keep = False)].sort_values(by=['DatedVehicleJourneyRef', 'RecordedAtTime']).shape
# Out:
# (142, 16)

# %%
# The records which have the same data in the "DatedVehicleJourneyRef" and "filename" columns
df_selected[df_selected.duplicated(subset = ['DatedVehicleJourneyRef', 'fileName'], keep = False)].sort_values(by=['DatedVehicleJourneyRef', 'RecordedAtTime']).shape
# Out:
# (5196, 16)

# %%
#Remove the rows which have the same data in the "DatedVehicleJourneyRef" and "RecordedAtTime" columns
df_final = df_selected.drop_duplicates(subset = ['DatedVehicleJourneyRef', 'RecordedAtTime'], keep=False)

# %%
# Check if the data is removed
df_final[df_final.duplicated(subset = ['DatedVehicleJourneyRef', 'RecordedAtTime'], keep = False)].sort_values(by=['DatedVehicleJourneyRef', 'RecordedAtTime'])
# Out:
# Empty DataFrame
# Columns: [LineRef, DirectionRef, DatedVehicleJourneyRef, DataFrameRef, JourneyPatternRef, OriginRef, DestinationRef, DestinationName, RecordedAtTime, Latitude, Longitude, Bearing, ProgressRate, progressStatus, fileName, time_dt]
# Index: []

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187758 entries, 0 to 208278
# Data columns (total 16 columns):
# LineRef                   187758 non-null object
# DirectionRef              187758 non-null int64
# DatedVehicleJourneyRef    187758 non-null object
# DataFrameRef              187758 non-null object
# JourneyPatternRef         187758 non-null object
# OriginRef                 187758 non-null object
# DestinationRef            187758 non-null object
# DestinationName           187758 non-null object
# RecordedAtTime            187758 non-null object
# Latitude                  187758 non-null float64
# Longitude                 187758 non-null float64
# Bearing                   187758 non-null float64
# ProgressRate              187758 non-null object
# progressStatus            187758 non-null object
# fileName                  187758 non-null object
# time_dt                   187758 non-null datetime64[ns, pytz.FixedOffset(-300)]
# dtypes: datetime64[ns, pytz.FixedOffset(-300)](1), float64(3), int64(1), object(11)
# memory usage: 24.4+ MB

# %%
def calcDif(_df, _timeOrigin):
    indexs = []
    lists = []

    for i in range(_df.shape[0]):

        indexs.append(_df.index[i])
        
        timePosTmp = (_df.iloc[i].time_dt - _timeOrigin).seconds
        if(timePosTmp < 0):
            print("Find Negative")
        
        lists.append(timePosTmp)
        
    return pd.Series(data = lists, index = indexs)

# %%
df_final.head()
# Out:
#         LineRef  DirectionRef                       DatedVehicleJourneyRef  \
# 0  MTA NYCT_Q16             1     MTA NYCT_CS_A9-Weekday-SDon-045000_Q16_5
# 1  MTA NYCT_M42             1     MTA NYCT_MQ_A9-Weekday-SDon-044900_M42_5
# 2    MTABC_QM34             1        MTABC_22501199-LGPA9-LG_A9-Weekday-10
# 3  MTA NYCT_Q43             1     MTA NYCT_QV_A9-Weekday-SDon-042600_Q43_7
# 4  MTA NYCT_Q31             1  MTA NYCT_CS_A9-Weekday-SDon-039500_MISC_740
#
#   DataFrameRef JourneyPatternRef   OriginRef DestinationRef  \
# 0   2019-02-12       MTA_Q160039  MTA_504445     MTA_804050
# 1   2019-02-12       MTA_M420134  MTA_403249     MTA_903082
# 2   2019-02-12      MTA_QM340039  MTA_504366     MTA_405403
# 3   2019-02-12       MTA_Q430188  MTA_502085     MTA_904095
# 4   2019-02-12       MTA_Q310171  MTA_501249     MTA_904095
#
#                        DestinationName                 RecordedAtTime  \
# 0  FLUSHING MAIN ST STATION via UTOPIA  2019-02-12T07:30:00.000-05:00
# 1                 42 ST PIER CROSSTOWN  2019-02-12T07:30:01.000-05:00
# 2          EAST MIDTOWN 55 ST via 3 AV  2019-02-12T07:30:01.000-05:00
# 3    LTD JAMAICA LIRR STA via HILLSIDE  2019-02-12T07:30:02.000-05:00
# 4                         JAMAICA LIRR  2019-02-12T07:30:02.000-05:00
#
#     Latitude  Longitude     Bearing    ProgressRate progressStatus  \
# 0  40.790069 -73.781871  253.178590  normalProgress           None
# 1  40.748384 -73.969951   53.841816  normalProgress           None
# 2  40.701709 -73.894871  108.928600  normalProgress           None
# 3  40.713097 -73.782032  196.189210  normalProgress           None
# 4  40.700268 -73.808673  291.037500  normalProgress           None
#
#                       fileName                   time_dt
# 0  BusData_20190212_073000.xml 2019-02-12 07:30:00-05:00
# 1  BusData_20190212_073000.xml 2019-02-12 07:30:01-05:00
# 2  BusData_20190212_073200.xml 2019-02-12 07:30:01-05:00
# 3  BusData_20190212_073200.xml 2019-02-12 07:30:02-05:00
# 4  BusData_20190212_073000.xml 2019-02-12 07:30:02-05:00

# %%
tor = pd.to_datetime('2019-02-12 07:00:00-0500')
df_final['TimePos'] = calcDif(df_final, tor)
# Out:
# /Users/HiroyukiKondo/.pyenv/versions/anaconda3-5.2.0/envs/anaconda3-5.2.0/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_final = df_final.sort_values(["DatedVehicleJourneyRef", "RecordedAtTime"])
df_final = df_final.reset_index().drop("index", axis = 1)

# %%
df_final.head()
# Out:
#           LineRef  DirectionRef                       DatedVehicleJourneyRef  \
# 0  MTA NYCT_SIM22             0  MTA NYCT_CA_E9-Weekday-SDon-038000_MISC_445
# 1  MTA NYCT_SIM22             0  MTA NYCT_CA_E9-Weekday-SDon-038000_MISC_445
# 2  MTA NYCT_SIM22             0  MTA NYCT_CA_E9-Weekday-SDon-038000_MISC_445
# 3  MTA NYCT_SIM22             0  MTA NYCT_CA_E9-Weekday-SDon-038000_MISC_445
# 4  MTA NYCT_SIM22             0  MTA NYCT_CA_E9-Weekday-SDon-039000_MISC_452
#
#   DataFrameRef JourneyPatternRef   OriginRef DestinationRef  \
# 0   2019-02-12     MTA_SIM220039  MTA_200994     MTA_402214
# 1   2019-02-12     MTA_SIM220039  MTA_200994     MTA_402214
# 2   2019-02-12     MTA_SIM220039  MTA_200994     MTA_402214
# 3   2019-02-12     MTA_SIM220039  MTA_200994     MTA_402214
# 4   2019-02-12     MTA_SIM220039  MTA_200994     MTA_402214
#
#                     DestinationName                 RecordedAtTime   Latitude  \
# 0  MIDTOWN via 42 ST via MADISON AV  2019-02-12T07:31:33.000-05:00  40.753887
# 1  MIDTOWN via 42 ST via MADISON AV  2019-02-12T07:33:40.000-05:00  40.756775
# 2  MIDTOWN via 42 ST via MADISON AV  2019-02-12T07:35:44.000-05:00  40.761900
# 3  MIDTOWN via 42 ST via MADISON AV  2019-02-12T07:37:55.000-05:00  40.762155
# 4  MIDTOWN via 42 ST via MADISON AV  2019-02-12T07:31:43.000-05:00  40.756294
#
#    Longitude     Bearing    ProgressRate progressStatus  \
# 0 -73.978481   54.360190  normalProgress           None
# 1 -73.976374   55.619656  normalProgress           None
# 2 -73.972634   54.223923  normalProgress           None
# 3 -73.972055  337.325900  normalProgress           None
# 4 -73.987574  336.999800  normalProgress           None
#
#                       fileName                   time_dt  TimePos
# 0  BusData_20190212_073200.xml 2019-02-12 07:31:33-05:00     1893
# 1  BusData_20190212_073400.xml 2019-02-12 07:33:40-05:00     2020
# 2  BusData_20190212_073600.xml 2019-02-12 07:35:44-05:00     2144
# 3  BusData_20190212_073800.xml 2019-02-12 07:37:55-05:00     2275
# 4  BusData_20190212_073200.xml 2019-02-12 07:31:43-05:00     1903

# %%
df_final_forSave = df_final[["LineRef","DirectionRef","DatedVehicleJourneyRef", "RecordedAtTime", "Latitude", "Longitude", "TimePos"]]

# %%
df_final_forSave.to_csv("data/analyzedData/20190212/Journey_s_07-30-00_e_09-30-00_normProg_for_vis_from_pandas.csv", index =False)

# %%
df_final_forSave.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187758 entries, 0 to 187757
# Data columns (total 7 columns):
# LineRef                   187758 non-null object
# DirectionRef              187758 non-null int64
# DatedVehicleJourneyRef    187758 non-null object
# RecordedAtTime            187758 non-null object
# Latitude                  187758 non-null float64
# Longitude                 187758 non-null float64
# TimePos                   187758 non-null int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 10.0+ MB
